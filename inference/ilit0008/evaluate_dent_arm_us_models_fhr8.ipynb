# %%
from ilipy import ClipTypes, Session, TrackIndex, ViewDistance
from ilipy.features import Bookmarks
from ilipyutils.ml_features.base import get_anomaly_ml_pred_types, AnomalyStatus, get_anomaly_types
from ilipyutils.ml_features.query import FeatureQuery

environment = "prod"
inspection_id = "0A49KLT3B7Y"

# %%
session = Session(environment=environment)
session.set_active_inspection(inspection_id)
bookmarks_interface = Bookmarks(connector=session.database_connector)
feature_query = FeatureQuery(
    session=session, bookmarks_interface=bookmarks_interface
)
# Out:
# PySettings.cpp(46): ilipy: Build 0.18.0.12853 3faa190ed0 release-ili-0.18 'Fri Dec 12 20:09:25 2025'
# PySettings.cpp(47): Paths modulePath: /home/zmirikha/ilipy/lib/python3.11/site-packages/ilipy, userHomePath: /home/zmirikha, identityPath: /home/zmirikha/.aws/ilipy
# Settings.cpp(246): Settings: loading settings from /home/zmirikha/ilipy/lib/python3.11/site-packages/ilipy/Data/Environments/defaults.json
# Settings.cpp(246): Settings: loading settings from /home/zmirikha/ilipy/lib/python3.11/site-packages/ilipy/Data/Environments/prod.json
# PyAuthenticator.cpp(239): Attempting an IAM role login as no username and password or environment variables were provided.
# CognitoAuthenticator.cpp(158): Using Cognito Credentials
# CognitoAuthenticator.cpp(842): Login Successful.
# CognitoAuthenticator.cpp(842): Login Successful.
# CognitoAuthenticator.cpp(883): Logged in as username: zahra.mirikharaji
# CognitoAuthenticator.cpp(883): Logged in as username: zahra.mirikharaji
# DatabaseWebSocket.cpp(153): WebSocket connection established to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# Versioning.cpp(1238): Database schema version=5.3.EC36650D47A2358F, code-generated schema version=5.3.EC36650D47A2358F
# HttpRequestPool.cpp(82): [HttpRequestPool] Host: storage-dvv-01.darkvision.local, Port: 8080, Concurrent Connections: 1
# HttpRequestPool.cpp(82): [HttpRequestPool] Host: storage-dvh-01.darkvision.local, Port: 8080, Concurrent Connections: 1
# RestApi.cpp(72): ApiService Ping Response (http://storage-dvv-01.darkvision.local:8080) : 200, 38ms
# RestApi.cpp(72): ApiService Ping Response (http://storage-dvh-01.darkvision.local:8080) : 200, 163ms
# PySession.cpp(84): Initialized with inspection: 0A49KLT3B7Y

# %% [markdown]
# ## Arm encoder v3 model evaluation

# %%
anomaly_type = next((anomaly_type for anomaly_type in get_anomaly_ml_pred_types() if 'Dent-Detection-v3' == anomaly_type.ml_model_info.model_name), None)
clips = session.get_clips_by_type(ClipTypes.ChannelData)
anomaly_status_stats_dict = {}
error_count = 0
for clip in clips:
    if clip.odometer_tick_range.min.value == clip.odometer_tick_range.max.value:
            print(f"Skipping empty clip {clip.clip_id}")
            continue
    clip_id = clip.clip_id
    clip_anomalies = feature_query.get_anomalies_by_clip_by_anomaly_type(
        inspection_id=inspection_id,
        clip_id=clip.clip_id,
        anomaly_type=anomaly_type,
    )
    print(f"Clip ID: {clip_id}, Number of Dent-Detection-v3 anomalies: {len(clip_anomalies)}")
    for anomaly in clip_anomalies:
        try:
            history = bookmarks_interface.get_anomaly_change_history(anomaly.feature_id)
            status_list= [h.feature.anomaly_status.name for h in history]
            if "Approved" in status_list or "ApprovedInherited" in status_list or "SizeAnomaly" in status_list:
                print(status_list)
                anomaly_status_stats_dict.setdefault("Approved" , 0)
                anomaly_status_stats_dict["Approved"] += 1
            else:
                anomaly_status_stats_dict.setdefault(status_list[0], 0)
                anomaly_status_stats_dict[status_list[0]] += 1
        except Exception as e:
            print(f"Error retrieving change history for anomaly {anomaly.feature_id}: {e}")
            error_count += 1

# %%
error_count

# %%
anomaly_status_stats_dict

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
# Create bar chart
statuses = list(anomaly_status_stats_dict.keys())
counts = list(anomaly_status_stats_dict.values())

plt.figure(figsize=(10, 6))
plt.bar(statuses, counts, color='steelblue', edgecolor='black')
plt.xlabel('Anomaly Status', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Anomaly Status Distribution for Dent-Detection-v3', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', alpha=0.3)
#add percentage on top as well



# Add count labels on top of bars
for i, (status, count) in enumerate(zip(statuses, counts)):
    plt.text(i, count, str(count), ha='center', va='bottom', fontsize=10)

plt.show()

# %%
get_anomaly_ml_pred_types()
anomaly_type = next((anomaly_type for anomaly_type in get_anomaly_ml_pred_types() if 'Ultrasound-Dent-v1' == anomaly_type.ml_model_info.model_name), None)
print(anomaly_type)
# Out:
# AnomalyTypeMLPred(name='DentPlain', anomaly_type_name='DentPlain', anomaly_identification_type_id=303, ml_model_info=MLModelInfo(model_name='Ultrasound-Dent-v1', model_id=12, model_score_bound=[0, 1], anomaly_type_name='DentPlain'))

# %%
anomaly_type = next((anomaly_type for anomaly_type in get_anomaly_ml_pred_types() if 'Dent-Ultrasound-v1' == anomaly_type.ml_model_info.model_name), None)
clips = session.get_clips_by_type(ClipTypes.ChannelData)
anomaly_status_stats_dict = {}
error_count = 0
for clip in clips:
    if clip.odometer_tick_range.min.value == clip.odometer_tick_range.max.value:
            print(f"Skipping empty clip {clip.clip_id}")
            continue
    clip_id = clip.clip_id
    clip_anomalies = feature_query.get_anomalies_by_clip_by_anomaly_type(
        inspection_id=inspection_id,
        clip_id=clip.clip_id,
        anomaly_type=anomaly_type,
    )
    print(f"Clip ID: {clip_id}, Number of Dent-Detection-v3 anomalies: {len(clip_anomalies)}")
    for anomaly in clip_anomalies:
        try:
            history = bookmarks_interface.get_anomaly_change_history(anomaly.feature_id)
            status_list= [h.feature.anomaly_status.name for h in history]
            if "Approved" in status_list or "ApprovedInherited" in status_list or "SizeAnomaly" in status_list or "QcSize" in status_list:
                print(status_list)
                anomaly_status_stats_dict.setdefault("Approved" , 0)
                anomaly_status_stats_dict["Approved"] += 1
            else:
                anomaly_status_stats_dict.setdefault(status_list[0], 0)
                anomaly_status_stats_dict[status_list[0]] += 1
        except Exception as e:
            print(f"Error retrieving change history for anomaly {anomaly.feature_id}: {e}")
            error_count += 1
# Out:
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# HttpRequestPool.cpp(82): [HttpRequestPool] Host: storage-dvv-01.darkvision.local, Port: 8080, Concurrent Connections: 3
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# Clip ID: 01-000-11YWD5E5, Number of Dent-Detection-v3 anomalies: 16795
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'QcSize', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'QcSize', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# CognitoAuthenticator.cpp(842): Login Successful.
# CognitoAuthenticator.cpp(883): Logged in as username: zahra.mirikharaji
# ['Nominal', 'Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'QcSize', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'SizeAnomaly', 'SizeAnomaly', 'SizeAnomaly', 'SizeAnomaly', 'SizeAnomaly']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Nominal', 'Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ...
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'Approved', 'SizeAnomaly', 'Nominal', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'QcSize', 'Approved', 'QcSize', 'QcSize', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'QcSize', 'QcSize', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'QcSize', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'QcSize', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'Nominal', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['FalsePositive', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['FalsePositive', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['FalsePositive', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'FalsePositive', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# ['Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'Approved', 'ReviewDetection', 'ReviewDetection']
# ['Nominal', 'Approved', 'ReviewDetection', 'ReviewDetection', 'ReviewDetection']
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DbHealthCheck.cpp(146): Database service health check complete: Healthy

# %%
anomaly_status_stats_dict
# Out:
# {'FalsePositive': 6549,
#  'Nominal': 278,
#  'Approved': 29,
#  'PoorDataQuality': 30,
#  'NeedsDiscovery': 27}
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
# Create bar chart
statuses = list(anomaly_status_stats_dict.keys())
counts = list(anomaly_status_stats_dict.values())

plt.figure(figsize=(10, 6))
plt.bar(statuses, counts, color='steelblue', edgecolor='black')
plt.xlabel('Anomaly Status', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Anomaly Status Distribution for Dent-Detection-v3', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', alpha=0.3)
#add percentage on top as well



# Add count labels on top of bars
for i, (status, count) in enumerate(zip(statuses, counts)):
    plt.text(i, count, str(count), ha='center', va='bottom', fontsize=10)

plt.show()
# Out:
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution

# %%
import pandas as pd
anomaly_data = []
dent_anomaly_types = [anomaly_type for anomaly_type in get_anomaly_types() if 'Dent' in anomaly_type.name]
clips = session.get_clips_by_type(ClipTypes.ChannelData)
anomaly_status_stats_dict = {}
error_count = 0
for clip in clips:
    if clip.odometer_tick_range.min.value == clip.odometer_tick_range.max.value:
            print(f"Skipping empty clip {clip.clip_id}")
            continue
    clip_id = clip.clip_id
    for dent_t in dent_anomaly_types:
        clip_anomalies = feature_query.get_anomalies_by_clip_by_anomaly_type(
            inspection_id=inspection_id,
            clip_id=clip.clip_id,
            anomaly_type=dent_t,
        )
        print(f"Clip ID: {clip_id}, Number of anomalies: {len(clip_anomalies)}")
        for anomaly in clip_anomalies:
            if anomaly.status == AnomalyStatus.APPROVED:
                # Collect anomaly data
                anomaly_data.append({
                    'anomaly_id': anomaly.feature_id,
                    'anomaly_type': anomaly.name,
                    'status': anomaly.status.name,
                    'clip_id': clip_id,
                    'tags': anomaly.tags  # if tags exist
                })

# Convert to DataFrame
anomalies_df = pd.DataFrame(anomaly_data)
display(anomalies_df)
# Out:
# Clip ID: 01-000-11YWD5E5, Number of anomalies: 0
# Clip ID: 01-000-11YWD5E5, Number of anomalies: 0
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# HttpRequestPool.cpp(58): readChunkFromServer() request not made... There may be an issue connecting to the host... [GET - storage-dvv-01.darkvision.local/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5]
# HttpRequestPool.cpp(291): Failed to acquire connection: http://storage-dvv-01.darkvision.local:8080/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5 GET code: 1058, value: AWS_IO_DNS_QUERY_FAILED - A query to dns failed to resolve.
# HttpRequestPool.cpp(291): Failed to acquire connection: http://storage-dvv-01.darkvision.local:8080/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5 GET code: 1058, value: AWS_IO_DNS_QUERY_FAILED - A query to dns failed to resolve.
# HttpRequestPool.cpp(58): readChunkFromServer() request not made... There may be an issue connecting to the host... [GET - storage-dvv-01.darkvision.local/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# HttpRequestPool.cpp(291): Failed to acquire connection: http://storage-dvv-01.darkvision.local:8080/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5 GET code: 1058, value: AWS_IO_DNS_QUERY_FAILED - A query to dns failed to resolve.
# HttpRequestPool.cpp(58): readChunkFromServer() request not made... There may be an issue connecting to the host... [GET - storage-dvv-01.darkvision.local/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5]
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# HttpRequestPool.cpp(291): Failed to acquire connection: http://storage-dvv-01.darkvision.local:8080/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5 GET code: 1058, value: AWS_IO_DNS_QUERY_FAILED - A query to dns failed to resolve.
# HttpRequestPool.cpp(58): readChunkFromServer() request not made... There may be an issue connecting to the host... [GET - storage-dvv-01.darkvision.local/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5]
# HttpRequestPool.cpp(291): Failed to acquire connection: http://storage-dvv-01.darkvision.local:8080/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5 GET code: 1058, value: AWS_IO_DNS_QUERY_FAILED - A query to dns failed to resolve.
# HttpRequestPool.cpp(58): readChunkFromServer() request not made... There may be an issue connecting to the host... [GET - storage-dvv-01.darkvision.local/dataset/chunk?chunkSize=280&fileGlob=%2A.dvdata&fileHash=3982614181&fileOffset=558029472&path=datasets/0A49KLT3B7Y/01-000-11YWD5E5]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 13
#      11 clip_id = clip.clip_id
#      12 for dent_t in dent_anomaly_types:
# ---> 13     clip_anomalies = feature_query.get_anomalies_by_clip_by_anomaly_type(
#      14         inspection_id=inspection_id,
#      15         clip_id=clip.clip_id,
#      16         anomaly_type=dent_t,
#      17     )
#      18     print(f"Clip ID: {clip_id}, Number of anomalies: {len(clip_anomalies)}")
#      19     for anomaly in clip_anomalies:
#
# File ~/Github/ILIWorkflows/ilipyutils/src/ilipyutils/ml_features/query.py:309, in FeatureQuery.get_anomalies_by_clip_by_anomaly_type(self, inspection_id, clip_id, anomaly_type, max_n_features, random_seed)
#     280 def get_anomalies_by_clip_by_anomaly_type(
#     281     self,
#     282     inspection_id: str,
#    (...)    286     random_seed: int | None = None,
#     287 ) -> list[AnomalyInfoWrap]:
#     288     """
#     289     Retrieves anomalies of a specific anomaly type for a given clip in a specific inspection.
#     290
#    (...)    307         A filtered list of anomaly info objects matching the given type.
#     308     """
# --> 309     return self._get_features_by_clip(
#     310         inspection_id=inspection_id,
#     311         clip_id=clip_id,
#     312         feature_getter_fn_ilipy=self.get_anomalies_cached,
#     313         feature_type=anomaly_type,
#     314         max_n_features=max_n_features,
#     315         random_seed=random_seed,
#     316     )
#
# File ~/Github/ILIWorkflows/ilipyutils/src/ilipyutils/ml_features/query.py:160, in FeatureQuery._get_features_by_clip(self, inspection_id, clip_id, feature_getter_fn_ilipy, feature_type, max_n_features, random_seed)
#     158         continue
#     159 try:
# --> 160     feature_info_wrap = ilipy_info_to_wrap_info(
#     161         feature_info,
#     162         session=self.session,
#     163         bookmarks_interface=self.bookmarks_interface,
#     164     )
#     165 except FeatureTypeNotSupportedError as e:
#     166     # Skip if the feature type is not recognized
#     167     logger.warning(
#     168         "Feature %s has an unknown type; skipping - %s",
#     169         feature_info,
#     170         e,
#     171     )
#
# File ~/Github/ILIWorkflows/ilipyutils/src/ilipyutils/ml_features/base/feature_info.py:475, in ilipy_info_to_wrap_info(feature_info, session, bookmarks_interface)
#     472 if isinstance(feature_info, AnomalyInfo):
#     473     # Check if the anomaly info is from ML prediction
#     474     if is_anomaly_info_from_ml_pred(anomaly_info=feature_info):
# --> 475         feature_info_ret = AnomalyInfoMLPred.from_ili_info(
#     476             anomaly_info=feature_info,
#     477             session=session,
#     478             bookmarks_interface=bookmarks_interface,
#     479         )
#     480     else:
#     481         feature_info_ret = AnomalyInfoWrap.from_ili_info(
#     482             anomaly_info=feature_info,
#     483             session=session,
#     484             bookmarks_interface=bookmarks_interface,
#     485         )
#
# File ~/Github/ILIWorkflows/ilipyutils/src/ilipyutils/ml_features/base/feature_info.py:365, in AnomalyInfoMLPred.from_ili_info(cls, anomaly_info, session, bookmarks_interface)
#     362 if custom_data:
#     363     custom_data = json.loads(custom_data.value)
# --> 365 feature_location = get_feature_loc_from_anomaly_info(
#     366     anomaly_info=anomaly_info,
#     367     session=session,
#     368 )
#     370 status_id = anomaly_info.feature.anomaly_status_type_id
#     371 status = AnomalyStatus.from_status_id(status_id, bookmarks_interface)
#
# File ~/Github/ILIWorkflows/ilipyutils/src/ilipyutils/ml_features/base/geometry_utils.py:511, in get_feature_loc_from_anomaly_info(anomaly_info, session)
#     507     else:
#     508         # This clip does not contain the feature
#     509         continue
# --> 511     frame_indices_range_dict = get_frame_indices_from_odo_ticks(
#     512         session=session,
#     513         clip=clip,
#     514         odo_ticks=odometer_ticks_range_in_clip,
#     515     )
#     517     location_track_row.append(
#     518         FeatureLocationClip(
#     519             clip=clip,
#    (...)    524         )
#     525     )
#     526 location_matrix.append(location_track_row)
#
# File ~/Github/ILIWorkflows/ilipyutils/src/ilipyutils/ml_features/base/geometry_utils.py:254, in get_frame_indices_from_odo_ticks(session, clip, odo_ticks)
#     247 image_profiles = {
#     248     ImageProfile.NegAngle,
#     249     ImageProfile.PosAngle,
#     250     ImageProfile.ZeroAngle,
#     251 }
#     253 for image_profile in image_profiles:
# --> 254     ch = ChannelDataReader(
#     255         session=session,
#     256         clip=clip,
#     257         image_profile=image_profile,
#     258     )
#     259     ret_dict[image_profile] = tuple(
#     260         ch.get_closest_frame_index_from_odometer_ticks(OdometerTicks(tick))
#     261         for tick in odo_ticks
#     262     )
#     263 return ret_dict
#
# RuntimeError: Failed to Read Chunk from WebService after 5 attempts
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# DbHealthCheck.cpp(84): Could not issue HTTP request to https://backend.ili-prod.darkvisiontech.com/healthz : [true|99]
# DatabaseWebSocket.cpp(173): WebSocket connection error: Unable to connect to backend.ili-prod.darkvisiontech.com on port 443, error: Temporary failure in name resolution
# ...
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DbHealthCheck.cpp(146): Database service health check complete: Healthy
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
#
# DatabaseWebSocket.cpp(173): WebSocket connection error: Expecting status 101 (Switching Protocol), got 401 status connecting to https://backend.ili-prod.darkvisiontech.com/dbservice/wsbin, HTTP Status line: HTTP/1.1 401
